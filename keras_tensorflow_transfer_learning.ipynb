# %% [markdown]
# # Using Transfer Learning (with the Inceptionv3 Model) and Keras Wrapper to do cat vs dog recognition

# %% [markdown]
# ## Imports

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.utils import np_utils
from keras import backend as K
from PIL import Image
import numpy as np
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Create base inception model, add fully-connected layer, freeze base layers, and compile

# %%
# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# cat vs dog prediction
predictions = Dense(2, activation='softmax')(x)

# this is the model we will train
model = Model(input=base_model.input, output=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
# Out:
# /Users/zachariahmiller/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`

# %% [markdown]
# ## Setting up images/class generator

# %%
# classes: dog = 1, cat = 0
width = 200
height = width

def augment(imgr):
    return imgr

def image_generator(basedir):
    cls = np.random.randint(0,1+1)
    fname = basedir
    if cls:
        fname += '/dog'
    else:
        fname += '/cat'
    imgpath = os.path.join(fname, np.random.choice(os.listdir(fname)))
    img = Image.open(imgpath)
    imgr = img.resize((width,height),resample=Image.ANTIALIAS)
    img_aug = augment(imgr)
    return img_aug, cls, imgpath

def get_batch(basedir, batch_size=25):
    batch=0
    images = np.empty(shape=(batch_size,width,height,3))
    classes = np.empty(shape=(batch_size))
    img_paths = []
    while batch < batch_size: 
        imag,clas,path = image_generator(basedir)
        images[batch] = imag
        images[batch]/= 255.
        classes[batch] = clas
        img_paths.append(path)
        batch+=1
    return images, classes, img_paths

# %% [markdown]
# ## For checking if images are loading correctly

# %%
from matplotlib.pyplot import imshow
# %matplotlib inline
images, classes, img_paths = get_batch('train', batch_size=10)
imshow(images[9])

# %% [markdown]
# ## Actually train the fully connected layer

# %%
# Takes a long time, Only use if you are sure
"""
batch_size = 100
images_per_epoch = 10000
num_batches = int(images_per_epoch/batch_size)
num_epoch = 2

for epoch in range(num_epoch):
    for batch in range(num_batches):
        print "Epoch: "+str(epoch)+"; Batch: "+str(batch)
        images, classes, img_paths = get_batch('train',batch_size)
        target = np_utils.to_categorical(classes)
        model.fit(images, target, verbose=1, batch_size=batch_size)
"""
# Out:
# Epoch: 0; Batch: 0
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 6.1107
# Epoch: 0; Batch: 1
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.4172
# Epoch: 0; Batch: 2
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 1.3476
# Epoch: 0; Batch: 3
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 3.6974
# Epoch: 0; Batch: 4
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 1.4524
# Epoch: 0; Batch: 5
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 1.1564
# Epoch: 0; Batch: 6
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.4881
# Epoch: 0; Batch: 7
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.5077
# Epoch: 0; Batch: 8
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.5409
# Epoch: 0; Batch: 9
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3503
# Epoch: 0; Batch: 10
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3059
# Epoch: 0; Batch: 11
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3083
# Epoch: 0; Batch: 12
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.4323
# Epoch: 0; Batch: 13
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.5084
# Epoch: 0; Batch: 14
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.4476
# Epoch: 0; Batch: 15
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3710
# Epoch: 0; Batch: 16
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.3298
# Epoch: 0; Batch: 17
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.6063
# Epoch: 0; Batch: 18
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 1.1181
# Epoch: 0; Batch: 19
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.8303
# Epoch: 0; Batch: 20
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.4334
# Epoch: 0; Batch: 21
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3836
# Epoch: 0; Batch: 22
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3141
# Epoch: 0; Batch: 23
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3378
# Epoch: 0; Batch: 24
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.5871
# Epoch: 0; Batch: 25
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3758
# Epoch: 0; Batch: 26
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2738
# Epoch: 0; Batch: 27
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2717
# Epoch: 0; Batch: 28
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3181
# Epoch: 0; Batch: 29
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.4561
# Epoch: 0; Batch: 30
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.6976
# Epoch: 0; Batch: 31
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 1.1456
# Epoch: 0; Batch: 32
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 1.0716
# Epoch: 0; Batch: 33
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2049
# Epoch: 0; Batch: 34
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2290
# Epoch: 0; Batch: 35
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.2359
# Epoch: 0; Batch: 36
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2796
# Epoch: 0; Batch: 37
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3460
# Epoch: 0; Batch: 38
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2900
# Epoch: 0; Batch: 39
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2219
# Epoch: 0; Batch: 40
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2384
# Epoch: 0; Batch: 41
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2315
# Epoch: 0; Batch: 42
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2583
# Epoch: 0; Batch: 43
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3344
# Epoch: 0; Batch: 44
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 1.0104
# Epoch: 0; Batch: 45
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 1.9074
# Epoch: 0; Batch: 46
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3420
# Epoch: 0; Batch: 47
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2366
# Epoch: 0; Batch: 48
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2025
# Epoch: 0; Batch: 49
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3785
# Epoch: 0; Batch: 50
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2321
# Epoch: 0; Batch: 51
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2266
# Epoch: 0; Batch: 52
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2343
# Epoch: 0; Batch: 53
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3048
# Epoch: 0; Batch: 54
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.9537
# Epoch: 0; Batch: 55
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 1.0917
# Epoch: 0; Batch: 56
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.5144
# Epoch: 0; Batch: 57
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2409
# Epoch: 0; Batch: 58
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2466
# Epoch: 0; Batch: 59
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2197
# Epoch: 0; Batch: 60
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.1948
# Epoch: 0; Batch: 61
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3596
# Epoch: 0; Batch: 62
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.7349
# Epoch: 0; Batch: 63
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.6557
# Epoch: 0; Batch: 64
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2383
# Epoch: 0; Batch: 65
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2140
# Epoch: 0; Batch: 66
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2187
# Epoch: 0; Batch: 67
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.4152
# Epoch: 0; Batch: 68
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 1.2071
# Epoch: 0; Batch: 69
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.9460
# Epoch: 0; Batch: 70
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3634
# Epoch: 0; Batch: 71
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2992
# Epoch: 0; Batch: 72
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2287
# Epoch: 0; Batch: 73
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1948
# Epoch: 0; Batch: 74
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.3325
# Epoch: 0; Batch: 75
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.2276
# Epoch: 0; Batch: 76
# Epoch 1/1
# 100/100 [==============================] - 25s - loss: 0.2238
# Epoch: 0; Batch: 77
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.1802
# Epoch: 0; Batch: 78
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.1289
# Epoch: 0; Batch: 79
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1731
# Epoch: 0; Batch: 80
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1605
# Epoch: 0; Batch: 81
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2725
# Epoch: 0; Batch: 82
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.6768
# Epoch: 0; Batch: 83
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.5877
# Epoch: 0; Batch: 84
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.2197
# Epoch: 0; Batch: 85
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1908
# Epoch: 0; Batch: 86
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1552
# Epoch: 0; Batch: 87
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.1476
# Epoch: 0; Batch: 88
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2788
# Epoch: 0; Batch: 89
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.4097
# Epoch: 0; Batch: 90
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.7330
# Epoch: 0; Batch: 91
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.6205
# Epoch: 0; Batch: 92
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2233
# Epoch: 0; Batch: 93
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2468
# Epoch: 0; Batch: 94
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2209
# Epoch: 0; Batch: 95
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2264
# Epoch: 0; Batch: 96
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2008
# Epoch: 0; Batch: 97
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2468
# Epoch: 0; Batch: 98
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3448
# Epoch: 0; Batch: 99
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.5739
# Epoch: 1; Batch: 0
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.5137
# Epoch: 1; Batch: 1
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3575
# Epoch: 1; Batch: 2
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.3922
# Epoch: 1; Batch: 3
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.3967
# Epoch: 1; Batch: 4
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2503
# Epoch: 1; Batch: 5
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1701
# Epoch: 1; Batch: 6
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.1931
# Epoch: 1; Batch: 7
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.1030
# Epoch: 1; Batch: 8
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2078
# Epoch: 1; Batch: 9
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2523
# Epoch: 1; Batch: 10
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.6679
# Epoch: 1; Batch: 11
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.5914
# Epoch: 1; Batch: 12
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3486
# Epoch: 1; Batch: 13
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1971
# Epoch: 1; Batch: 14
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1683
# Epoch: 1; Batch: 15
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.2173
# Epoch: 1; Batch: 16
# Epoch 1/1
# 100/100 [==============================] - 25s - loss: 0.2947
# Epoch: 1; Batch: 17
# Epoch 1/1
# 100/100 [==============================] - 27s - loss: 0.2328
# Epoch: 1; Batch: 18
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1791
# Epoch: 1; Batch: 19
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2383
# Epoch: 1; Batch: 20
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.1779
# Epoch: 1; Batch: 21
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.2411
# Epoch: 1; Batch: 22
# Epoch 1/1
# 100/100 [==============================] - 24s - loss: 0.3207
# Epoch: 1; Batch: 23
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2642
# Epoch: 1; Batch: 24
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.4074
# Epoch: 1; Batch: 25
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.2038
# Epoch: 1; Batch: 26
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2276
# Epoch: 1; Batch: 27
# Epoch 1/1
# 100/100 [==============================] - 25s - loss: 0.1708
# Epoch: 1; Batch: 28
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.2448
# Epoch: 1; Batch: 29
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.1593
# Epoch: 1; Batch: 30
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.1964
# Epoch: 1; Batch: 31
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2328
# Epoch: 1; Batch: 32
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2725
# Epoch: 1; Batch: 33
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.3061
# Epoch: 1; Batch: 34
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2909
# Epoch: 1; Batch: 35
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2616
# Epoch: 1; Batch: 36
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.3787
# Epoch: 1; Batch: 37
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.3606
# Epoch: 1; Batch: 38
# Epoch 1/1
# 100/100 [==============================] - 25s - loss: 0.3214
# Epoch: 1; Batch: 39
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2413
# Epoch: 1; Batch: 40
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.1806
# Epoch: 1; Batch: 41
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.1976
# Epoch: 1; Batch: 42
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.3159
# Epoch: 1; Batch: 43
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.4282
# Epoch: 1; Batch: 44
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2351
# Epoch: 1; Batch: 45
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2670
# Epoch: 1; Batch: 46
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.3693
# Epoch: 1; Batch: 47
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.4735
# Epoch: 1; Batch: 48
# Epoch 1/1
# 100/100 [==============================] - 25s - loss: 0.1754
# Epoch: 1; Batch: 49
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2005
# Epoch: 1; Batch: 50
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.2195
# Epoch: 1; Batch: 51
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.2548
# Epoch: 1; Batch: 52
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.3044
# Epoch: 1; Batch: 53
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.2377
# Epoch: 1; Batch: 54
# Epoch 1/1
# 100/100 [==============================] - 23s - loss: 0.2494
# Epoch: 1; Batch: 55
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2958
# Epoch: 1; Batch: 56
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1212
# Epoch: 1; Batch: 57
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2555
# Epoch: 1; Batch: 58
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1715
# Epoch: 1; Batch: 59
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1963
# Epoch: 1; Batch: 60
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1784
# Epoch: 1; Batch: 61
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3543
# Epoch: 1; Batch: 62
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.3522
# Epoch: 1; Batch: 63
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.1994
# Epoch: 1; Batch: 64
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2011
# Epoch: 1; Batch: 65
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2132
# Epoch: 1; Batch: 66
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2195
# Epoch: 1; Batch: 67
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.1543
# Epoch: 1; Batch: 68
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1437
# Epoch: 1; Batch: 69
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1674
# Epoch: 1; Batch: 70
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2652
# Epoch: 1; Batch: 71
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.6064
# Epoch: 1; Batch: 72
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.3080
# Epoch: 1; Batch: 73
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.2335
# Epoch: 1; Batch: 74
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2277
# Epoch: 1; Batch: 75
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.2047
# Epoch: 1; Batch: 76
# Epoch 1/1
# 100/100 [==============================] - 22s - loss: 0.2654
# Epoch: 1; Batch: 77
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2838
# Epoch: 1; Batch: 78
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.4383
# Epoch: 1; Batch: 79
# Epoch 1/1
# 100/100 [==============================] - 17s - loss: 0.4397
# Epoch: 1; Batch: 80
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2248
# Epoch: 1; Batch: 81
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2197
# Epoch: 1; Batch: 82
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.3823
# Epoch: 1; Batch: 83
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2788
# Epoch: 1; Batch: 84
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.1733
# Epoch: 1; Batch: 85
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.1938
# Epoch: 1; Batch: 86
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.1668
# Epoch: 1; Batch: 87
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2186
# Epoch: 1; Batch: 88
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.4247
# Epoch: 1; Batch: 89
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2332
# Epoch: 1; Batch: 90
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.1534
# Epoch: 1; Batch: 91
# Epoch 1/1
# 100/100 [==============================] - 18s - loss: 0.2432
# Epoch: 1; Batch: 92
# Epoch 1/1
# 100/100 [==============================] - 19s - loss: 0.1671
# Epoch: 1; Batch: 93
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.2176
# Epoch: 1; Batch: 94
# Epoch 1/1
# 100/100 [==============================] - 21s - loss: 0.1638
# Epoch: 1; Batch: 95
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.1958
# Epoch: 1; Batch: 96
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.5227
# Epoch: 1; Batch: 97
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.7389
# Epoch: 1; Batch: 98
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.3372
# Epoch: 1; Batch: 99
# Epoch 1/1
# 100/100 [==============================] - 20s - loss: 0.4397

# %%
#model.save_weights('first_try.h5')

# %% [markdown]
# ## Test Model

# %%
# use to load weights if you don't want to retrain
model.load_weights("first_try.h5")

# %%
pos_dog, pos_cat, neg_dog, neg_cat = 0, 0, 0, 0
num_val_images = 1000
images, classes, img_paths = get_batch('test',num_val_images)
target = np_utils.to_categorical(classes)
#scores = model.evaluate(images, target, verbose=1) # Checks log loss cross-entropy
predictions = model.predict(images, batch_size=num_val_images, verbose=1)

for ypred, ytrue in zip(predictions,classes):
    y = int(np.argmax(ypred))
    yt = int(ytrue)
    if yt == y:
        if yt:
            pos_dog+=1
        else:
            pos_cat+=1
    else:
        if yt:
            neg_dog+=1
        else:
            neg_cat+=1
            
acc = float(pos_dog+pos_cat)/float(len(classes))
print "Acc: " + str(acc)
# Out:
# 1000/1000 [==============================] - 247s
# Acc: 0.927

# %%
# Get a single sample from test and print prediction beside image
num_val_images = 1
images, classes, img_paths = get_batch('test',num_val_images)
target = np_utils.to_categorical(classes)
prediction = model.predict(images, batch_size=num_val_images, verbose=1)
imshow(images[0])
print prediction
# Out:
# 1/1 [==============================] - 0s
# [[  9.99207914e-01   7.92119361e-04]]

# %% [markdown]
# ## Predict on a Specific Image

# %%
def image_to_predict(imgpath):
    img = Image.open(imgpath)
    imgr = img.resize((width,height),resample=Image.ANTIALIAS)
    img_data = np.array(imgr)/255.
    return img_data

img_to_predict = np.empty(shape=(1,200,200,3))
pic = image_to_predict('topredict/duckhuntdog.jpg')
img_to_predict[0] = pic
imshow(img_to_predict[0])
prediction = model.predict(img_to_predict, batch_size=1, verbose=1)
print prediction
# Out:
# 1/1 [==============================] - 0s
# [[ 0.15539505  0.84460497]]
